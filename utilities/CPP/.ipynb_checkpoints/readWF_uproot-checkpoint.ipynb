# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
import seaborn as sns
import uproot

# %%
file = uproot.open("../FILE.root")

# %%
file.classnames()
file["data"].keys()
# Out:
# ['ch0', 'time', 'xinc']

# %%
file["ch0"].array()
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# /tmp/ipykernel_9180/4028124150.py in <module>
# ----> 1 file["ch0"].array()
#
# /gpfs/gibbs/project/maruyama/jat89/conda_envs/ROOT6/lib/python3.8/site-packages/uproot/reading.py in __getitem__(self, where)
#    2079
#    2080         else:
# -> 2081             return self.key(where).get()
#    2082
#    2083     @property
#
# /gpfs/gibbs/project/maruyama/jat89/conda_envs/ROOT6/lib/python3.8/site-packages/uproot/reading.py in key(self, where)
#    2029             return last
#    2030         elif cycle is None:
# -> 2031             raise uproot.KeyInFileError(
#    2032                 item, cycle="any", keys=self.keys(), file_path=self._file.file_path
#    2033             )
#
# KeyInFileError: not found: 'ch0' (with any cycle number)
#
#     Available keys: 'data;1'
#
# in file ../FILE.root

# %%
wf = uproot.open("../FILE.root:data")

# %%
wf_array = wf["ch0"].array(library="np")

# %%
plt.figure(figsize = (8,5))
for i in range(0,10):
    plt.plot(wf_array[i])
plt.xlim(300,600)
# Out:
# (300.0, 600.0)

# %%
integ_ADC = []
for element in wf_array:
    bsl = np.mean(element[0:20])
    array_trace = np.array(np.ones(len(element)))
    for i in range(len(element)):
        array_trace[i] = (-element[i]+bsl)
    integ_ADC.append(sum(array_trace))

# %%
plt.hist(integ_ADC, bins = 100, range = (0,50000), histtype="step");
plt.yscale('log')
